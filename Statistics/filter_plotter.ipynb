# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
from helper import save_exr_images_to_png

# %%
# Load the dictionary of ID to metric values

with open("id_metric_dict.pkl", "rb") as f:
    metrics = pickle.load(f)
print(metrics)

# %%
# plot histogram of metrics
plt.hist(list(metrics.values()), bins=25)
# log y axis
plt.yscale("log")

plt.show()

# %%
# Print IDs with metric above threshold and some example metrics for specific IDs
def check_metrics(metrics, threshold, gt=True):
    ids_to_save = [id for id, div in metrics.items() if (gt and div > threshold) or (not gt and div < threshold) ]
    if gt:
        print("IDs with metric above " + str(threshold))
    else:
        print("IDs with metric below " + str(threshold))
    print(str(len(ids_to_save)) + " out of " + str(len(metrics)) + " total IDs")
    print(str(ids_to_save))
    print("Different Scene example 1000101:", metrics[1000101])
    print("Different Scene example 1000171:", metrics[1000171])
    print("Correct example 1000166:", metrics[1000166])
    print("Correct example 1000033:", metrics[1000033])
    print("Wrong Times example 1000019:", metrics[1000019])
    print("Wrong Times example 1000812:", metrics[1000812])
    return ids_to_save

# %%
# Save IDs to PNGs for manual inspection
path_for_inspection = r"D:\Subset\EXR_to_PNG"

save_exr_images_to_png(ids_to_save, path_for_inspection)

# %% [markdown]
# ## MSE over times after DoG
# (Thr 6000 -> ~10%, different scene)

# %%
# Load the dictionary of ID to metric values

with open("id_metric_dict_times_mse_conv.pkl", "rb") as f:
    metrics = pickle.load(f)
print(metrics)


# plot histogram of metrics
plt.hist(list(metrics.values()), bins=25)
# log y axis
plt.yscale("log")

plt.show()
# Out:
# {1000003: np.float32(240.29712), 1000004: np.float32(293.03116), 1000005: np.float32(90.6841), 1000006: np.float32(31.090784), 1000008: np.float32(6.0078983), 1000010: np.float32(21.037638), 1000011: np.float32(23.603548), 1000012: np.float32(415.528), 1000014: np.float32(15.378996), 1000015: np.float32(87.23387), 1000017: np.float32(244.35059), 1000018: np.float32(115.941025), 1000019: np.float32(60.56817), 1000021: np.float32(155.56328), 1000023: np.float32(178.04025), 1000025: np.float32(70.61779), 1000026: np.float32(50.61263), 1000033: np.float32(972.45624), 1000037: np.float32(51.837963), 1000040: np.float32(176.53271), 1000042: np.float32(14.747515), 1000043: np.float32(241.25786), 1000045: np.float32(37.915962), 1000046: np.float32(6.6041007), 1000048: np.float32(21.359846), 1000049: np.float32(132.05028), 1000050: np.float32(70.44493), 1000053: np.float32(30.41579), 1000056: np.float32(56.868652), 1000059: np.float32(176.08939), 1000060: np.float32(227.77213), 1000061: np.float32(68.74216), 1000063: np.float32(114.15946), 1000064: np.float32(109.144066), 1000068: np.float32(371.3972), 1000072: np.float32(37.659607), 1000078: np.float32(49.45903), 1000085: np.float32(57.36255), 1000087: np.float32(110.47524), 1000088: np.float32(20.150976), 1000089: np.float32(65.640015), 1000094: np.float32(64.71572), 1000095: np.float32(417.11322), 1000096: np.float32(65.112015), 1000097: np.float32(102.59288), 1000101: np.float32(825.9713), 1000105: np.float32(105.88906), 1000106: np.float32(55.994923), 1000107: np.float32(142.71373), 1000108: np.float32(123.26481), 1000110: np.float32(20.502584), 1000113: np.float32(41.053383), 1000115: np.float32(99.1803), 1000116: np.float32(47.853863), 1000120: np.float32(486.1211), 1000123: np.float32(117.51444), 1000131: np.float32(29.868979), 1000132: np.float32(182.90044), 1000136: np.float32(582.32874), 1000137: np.float32(524.8144), 1000139: np.float32(474.79916), 1000146: np.float32(105.14586), 1000152: np.float32(1294.592), 1000154: np.float32(65.280174), 1000156: np.float32(62.43792), 1000158: np.float32(15.520109), 1000162: np.float32(1080.3246), 1000166: np.float32(253.37715), 1000168: np.float32(105.642105), 1000171: np.float32(1368.4272), 1000174: np.float32(446.21783), 1000176: np.float32(68.828), 1000183: np.float32(99.707115), 1000185: np.float32(39.314156), 1000188: np.float32(69.198425), 1000189: np.float32(106.08425), 1000194: np.float32(40.066765), 1000197: np.float32(251.3604), 1000202: np.float32(16.765432), 1000209: np.float32(45.4326), 1000212: np.float32(153.50537), 1000215: np.float32(43.55579), 1000226: np.float32(1.3852621), 1000233: np.float32(53.420784), 1000234: np.float32(3.5125446), 1000235: np.float32(136.93515), 1000237: np.float32(137.24678), 1000240: np.float32(2.5553262), 1000251: np.float32(324.88983), 1000259: np.float32(70.24736), 1000266: np.float32(2.9586751), 1000271: np.float32(30.777985), 1000297: np.float32(54.681396), 1000301: np.float32(8.7102165), 1000303: np.float32(353.6828), 1000305: np.float32(218.19759), 1000306: np.float32(2.7434773), 1000321: np.float32(53.153847), 1000325: np.float32(17.848476), 1000326: np.float32(499.91733), 1000337: np.float32(9.406377), 1000339: np.float32(191.68828), 1000341: np.float32(267.2756), 1000342: np.float32(127.754555), 1000373: np.float32(143.17354), 1000375: np.float32(6.7828455), 1000379: np.float32(133.78949), 1000381: np.float32(244.86917), 1000385: np.float32(165.85867), 1000388: np.float32(19.964), 1000392: np.float32(8.526771), 1000398: np.float32(486.67496), 1000404: np.float32(221.57137), 1000406: np.float32(29.34451), 1000415: np.float32(745.44617), 1000424: np.float32(99.67537), 1000426: np.float32(9.300541), 1000427: np.float32(278.82693), 1000431: np.float32(45.86535), 1000432: np.float32(217.11218), 1000434: np.float32(140.72992), 1000437: np.float32(507.57855), 1000442: np.float32(193.22641), 1000445: np.float32(113.57267), 1000456: np.float32(31.460032), 1000461: np.float32(131.86684), 1000 ...

# %%
# Print IDs with metric above threshold and some example metrics for specific IDs

check_metrics(metrics, threshold=600)
# Out:
# IDs with metric above 600
# 56 out of 553 total IDs
# [1000033, 1000101, 1000152, 1000162, 1000171, 1000415, 1000774, 1000970, 1001735, 1002533, 1002661, 1006419, 1036087, 1036088, 1036111, 1036130, 1036131, 1036132, 1036134, 1036137, 1036141, 1036143, 1036145, 1036146, 1036148, 1036157, 1036158, 1036159, 1036160, 1036162, 1036163, 1036164, 1036165, 1036178, 1036187, 1036188, 1036189, 1036190, 1036216, 1036229, 1036230, 1036236, 1036240, 1036241, 1036244, 1036245, 1036250, 1036251, 1036270, 1036272, 1036273, 1036275, 1036281, 1036285, 1036291, 1036298]
# Different Scene example 1000101: 825.9713
# Different Scene example 1000171: 1368.4272
# Correct example 1000166: 253.37715
# Correct example 1000033: 972.45624
# Wrong Times example 1000019: 60.56817
# Wrong Times example 1000812: 56.004326

# %% [markdown]
# ## MSE over Times no night
# (Bad)

# %%
# Load the dictionary of ID to metric values

with open("id_metric_dict_times_mse_no0.pkl", "rb") as f:
    metrics = pickle.load(f)
print(metrics)


# plot histogram of metrics
plt.hist(list(metrics.values()), bins=25)
# log y axis
plt.yscale("log")

plt.show()
# Out:
# {1000003: np.float32(0.023352148), 1000004: np.float32(0.010805424), 1000005: np.float32(0.016511451), 1000006: np.float32(0.006149535), 1000008: np.float32(0.0030822041), 1000010: np.float32(0.09948039), 1000011: np.float32(0.015048347), 1000012: np.float32(0.008916663), 1000014: np.float32(0.007565516), 1000015: np.float32(0.030085638), 1000017: np.float32(0.081110165), 1000018: np.float32(0.008722773), 1000019: np.float32(0.010585378), 1000021: np.float32(0.22395214), 1000023: np.float32(0.017322639), 1000025: np.float32(0.009302047), 1000026: np.float32(0.021581395), 1000033: np.float32(0.0131349), 1000037: np.float32(0.01126797), 1000040: np.float32(0.07833938), 1000042: np.float32(0.02706123), 1000043: np.float32(0.008788971), 1000045: np.float32(0.0072541004), 1000046: np.float32(0.010619712), 1000048: np.float32(0.048526306), 1000049: np.float32(0.007948462), 1000050: np.float32(0.017251119), 1000053: np.float32(0.021054192), 1000056: np.float32(0.010933875), 1000059: np.float32(0.018910531), 1000060: np.float32(0.12943405), 1000061: np.float32(0.020518001), 1000063: np.float32(0.004322802), 1000064: np.float32(0.026553541), 1000068: np.float32(0.010226716), 1000072: np.float32(0.0082121445), 1000078: np.float32(0.008446618), 1000085: np.float32(0.023084309), 1000087: np.float32(0.07685609), 1000088: np.float32(0.022486307), 1000089: np.float32(0.028212056), 1000094: np.float32(0.015048285), 1000095: np.float32(0.25430256), 1000096: np.float32(0.19462362), 1000097: np.float32(0.36378202), 1000101: np.float32(0.032531668), 1000105: np.float32(0.018292766), 1000106: np.float32(0.039827187), 1000107: np.float32(0.019024778), 1000108: np.float32(0.02176075), 1000110: np.float32(0.014637724), 1000113: np.float32(0.007977701), 1000115: np.float32(0.022685487), 1000116: np.float32(0.013224025), 1000120: np.float32(0.023567697), 1000123: np.float32(0.40426278), 1000131: np.float32(0.025531601), 1000132: np.float32(0.10881034), 1000136: np.float32(0.04822582), 1000137: np.float32(0.0055031544), 1000139: np.float32(0.17776124), 1000146: np.float32(0.31364155), 1000152: np.float32(0.11653949), 1000154: np.float32(0.013190177), 1000156: np.float32(0.056421973), 1000158: np.float32(0.016209044), 1000162: np.float32(0.16701217), 1000166: np.float32(0.45041442), 1000168: np.float32(0.006603463), 1000171: np.float32(0.02205168), 1000174: np.float32(0.25028008), 1000176: np.float32(0.017020464), 1000183: np.float32(0.007643179), 1000185: np.float32(0.005397556), 1000188: np.float32(0.08420287), 1000189: np.float32(0.045069925), 1000194: np.float32(0.023514748), 1000197: np.float32(0.008237421), 1000202: np.float32(0.50334245), 1000209: np.float32(0.014662747), 1000212: np.float32(0.014451464), 1000215: np.float32(0.1237167), 1000226: np.float32(0.059434474), 1000233: np.float32(0.00311399), 1000234: np.float32(0.02164555), 1000235: np.float32(0.47021237), 1000237: np.float32(0.24384053), 1000240: np.float32(0.010786792), 1000251: np.float32(0.010217299), 1000259: np.float32(0.0053105424), 1000266: np.float32(0.005815773), 1000271: np.float32(0.49377522), 1000297: np.float32(0.0201637), 1000301: np.float32(0.0063561527), 1000303: np.float32(0.04115569), 1000305: np.float32(0.010006371), 1000306: np.float32(0.8314212), 1000321: np.float32(0.016399998), 1000325: np.float32(0.0065739565), 1000326: np.float32(0.07561318), 1000337: np.float32(0.07552458), 1000339: np.float32(0.03184489), 1000341: np.float32(0.13650534), 1000342: np.float32(0.010509172), 1000373: np.float32(0.1404959), 1000375: np.float32(0.4154958), 1000379: np.float32(0.020365674), 1000381: np.float32(0.16875866), 1000385: np.float32(0.017255198), 1000388: np.float32(0.28005177), 1000392: np.float32(0.012151336), 1000398: np.float32(0.013142377), 1000404: np.float32(0.01024246), 1000406: np.float32(0.03783583), 1000415: np.float32(0.11062731), 1000424: np.float32(0.012006184), 1000426: np.float32(0.007470975), 1000427: np.float32(0.022378262), 1000431: np.float32(0.01182566 ...

# %%
check_metrics(metrics, threshold=1)
# Out:
# IDs with metric above 1
# 46 out of 553 total IDs
# [1023968, 1028330, 1031718, 1031720, 1031806, 1031842, 1031886, 1031911, 1031914, 1031919, 1031920, 1031944, 1031947, 1031956, 1032031, 1032127, 1032324, 1032330, 1032495, 1032500, 1032501, 1032503, 1032755, 1033008, 1033010, 1033018, 1033022, 1035733, 1035774, 1035778, 1035847, 1035848, 1035857, 1035858, 1035863, 1035864, 1035872, 1035873, 1035879, 1035882, 1035887, 1035888, 1035889, 1035950, 1036049, 1036056]
# Different Scene example 1000101: 0.032531668
# Different Scene example 1000171: 0.02205168
# Correct example 1000166: 0.45041442
# Correct example 1000033: 0.0131349
# Wrong Times example 1000019: 0.010585378
# Wrong Times example 1000812: 0.029387131
# [1023968,
#  1028330,
#  1031718,
#  1031720,
#  1031806,
#  1031842,
#  1031886,
#  1031911,
#  1031914,
#  1031919,
#  1031920,
#  1031944,
#  1031947,
#  1031956,
#  1032031,
#  1032127,
#  1032324,
#  1032330,
#  1032495,
#  1032500,
#  1032501,
#  1032503,
#  1032755,
#  1033008,
#  1033010,
#  1033018,
#  1033022,
#  1035733,
#  1035774,
#  1035778,
#  1035847,
#  1035848,
#  1035857,
#  1035858,
#  1035863,
#  1035864,
#  1035872,
#  1035873,
#  1035879,
#  1035882,
#  1035887,
#  1035888,
#  1035889,
#  1035950,
#  1036049,
#  1036056]

# %% [markdown]
# ## MSE png exr all times DoG

# %%
# Load the dictionary of ID to metric values

with open("id_metric_dict_times_mse_no0.pkl", "rb") as f:
    metrics = pickle.load(f)
print(metrics)


# plot histogram of metrics
plt.hist(list(metrics.values()), bins=25)
# log y axis
plt.yscale("log")

plt.show()
# Out:
# {1000003: np.float32(0.023352148), 1000004: np.float32(0.010805424), 1000005: np.float32(0.016511451), 1000006: np.float32(0.006149535), 1000008: np.float32(0.0030822041), 1000010: np.float32(0.09948039), 1000011: np.float32(0.015048347), 1000012: np.float32(0.008916663), 1000014: np.float32(0.007565516), 1000015: np.float32(0.030085638), 1000017: np.float32(0.081110165), 1000018: np.float32(0.008722773), 1000019: np.float32(0.010585378), 1000021: np.float32(0.22395214), 1000023: np.float32(0.017322639), 1000025: np.float32(0.009302047), 1000026: np.float32(0.021581395), 1000033: np.float32(0.0131349), 1000037: np.float32(0.01126797), 1000040: np.float32(0.07833938), 1000042: np.float32(0.02706123), 1000043: np.float32(0.008788971), 1000045: np.float32(0.0072541004), 1000046: np.float32(0.010619712), 1000048: np.float32(0.048526306), 1000049: np.float32(0.007948462), 1000050: np.float32(0.017251119), 1000053: np.float32(0.021054192), 1000056: np.float32(0.010933875), 1000059: np.float32(0.018910531), 1000060: np.float32(0.12943405), 1000061: np.float32(0.020518001), 1000063: np.float32(0.004322802), 1000064: np.float32(0.026553541), 1000068: np.float32(0.010226716), 1000072: np.float32(0.0082121445), 1000078: np.float32(0.008446618), 1000085: np.float32(0.023084309), 1000087: np.float32(0.07685609), 1000088: np.float32(0.022486307), 1000089: np.float32(0.028212056), 1000094: np.float32(0.015048285), 1000095: np.float32(0.25430256), 1000096: np.float32(0.19462362), 1000097: np.float32(0.36378202), 1000101: np.float32(0.032531668), 1000105: np.float32(0.018292766), 1000106: np.float32(0.039827187), 1000107: np.float32(0.019024778), 1000108: np.float32(0.02176075), 1000110: np.float32(0.014637724), 1000113: np.float32(0.007977701), 1000115: np.float32(0.022685487), 1000116: np.float32(0.013224025), 1000120: np.float32(0.023567697), 1000123: np.float32(0.40426278), 1000131: np.float32(0.025531601), 1000132: np.float32(0.10881034), 1000136: np.float32(0.04822582), 1000137: np.float32(0.0055031544), 1000139: np.float32(0.17776124), 1000146: np.float32(0.31364155), 1000152: np.float32(0.11653949), 1000154: np.float32(0.013190177), 1000156: np.float32(0.056421973), 1000158: np.float32(0.016209044), 1000162: np.float32(0.16701217), 1000166: np.float32(0.45041442), 1000168: np.float32(0.006603463), 1000171: np.float32(0.02205168), 1000174: np.float32(0.25028008), 1000176: np.float32(0.017020464), 1000183: np.float32(0.007643179), 1000185: np.float32(0.005397556), 1000188: np.float32(0.08420287), 1000189: np.float32(0.045069925), 1000194: np.float32(0.023514748), 1000197: np.float32(0.008237421), 1000202: np.float32(0.50334245), 1000209: np.float32(0.014662747), 1000212: np.float32(0.014451464), 1000215: np.float32(0.1237167), 1000226: np.float32(0.059434474), 1000233: np.float32(0.00311399), 1000234: np.float32(0.02164555), 1000235: np.float32(0.47021237), 1000237: np.float32(0.24384053), 1000240: np.float32(0.010786792), 1000251: np.float32(0.010217299), 1000259: np.float32(0.0053105424), 1000266: np.float32(0.005815773), 1000271: np.float32(0.49377522), 1000297: np.float32(0.0201637), 1000301: np.float32(0.0063561527), 1000303: np.float32(0.04115569), 1000305: np.float32(0.010006371), 1000306: np.float32(0.8314212), 1000321: np.float32(0.016399998), 1000325: np.float32(0.0065739565), 1000326: np.float32(0.07561318), 1000337: np.float32(0.07552458), 1000339: np.float32(0.03184489), 1000341: np.float32(0.13650534), 1000342: np.float32(0.010509172), 1000373: np.float32(0.1404959), 1000375: np.float32(0.4154958), 1000379: np.float32(0.020365674), 1000381: np.float32(0.16875866), 1000385: np.float32(0.017255198), 1000388: np.float32(0.28005177), 1000392: np.float32(0.012151336), 1000398: np.float32(0.013142377), 1000404: np.float32(0.01024246), 1000406: np.float32(0.03783583), 1000415: np.float32(0.11062731), 1000424: np.float32(0.012006184), 1000426: np.float32(0.007470975), 1000427: np.float32(0.022378262), 1000431: np.float32(0.01182566 ...

# %%
check_metrics(metrics, threshold=1.5)
# Out:
# IDs with metric above 1.5
# 35 out of 553 total IDs
# [1031718, 1031720, 1031842, 1031886, 1031911, 1031914, 1031919, 1031920, 1031947, 1031956, 1032127, 1032330, 1032495, 1032501, 1032503, 1032755, 1033008, 1033010, 1033018, 1033022, 1035778, 1035847, 1035848, 1035857, 1035858, 1035863, 1035864, 1035872, 1035873, 1035879, 1035882, 1035887, 1035888, 1036049, 1036056]
# Different Scene example 1000101: 0.032531668
# Different Scene example 1000171: 0.02205168
# Correct example 1000166: 0.45041442
# Correct example 1000033: 0.0131349
# Wrong Times example 1000019: 0.010585378
# Wrong Times example 1000812: 0.029387131
# [1031718,
#  1031720,
#  1031842,
#  1031886,
#  1031911,
#  1031914,
#  1031919,
#  1031920,
#  1031947,
#  1031956,
#  1032127,
#  1032330,
#  1032495,
#  1032501,
#  1032503,
#  1032755,
#  1033008,
#  1033010,
#  1033018,
#  1033022,
#  1035778,
#  1035847,
#  1035848,
#  1035857,
#  1035858,
#  1035863,
#  1035864,
#  1035872,
#  1035873,
#  1035879,
#  1035882,
#  1035887,
#  1035888,
#  1036049,
#  1036056]

# %% [markdown]
# ## MSE MIN over Times

# %%
# Load the dictionary of ID to metric values

with open("id_metric_dict_times_mse_min.pkl", "rb") as f:
    metrics = pickle.load(f)
print(metrics)


# plot histogram of metrics
plt.hist(list(metrics.values()), bins=25)
# log y axis
plt.yscale("log")

plt.show()
# Out:
# {1000003: np.float32(0.016682051), 1000004: np.float32(0.012619606), 1000005: np.float32(0.00043006442), 1000006: np.float32(0.0021989488), 1000008: np.float32(0.00046089618), 1000010: np.float32(0.052169222), 1000011: np.float32(0.0050917175), 1000012: np.float32(0.0070886062), 1000014: np.float32(0.0055354834), 1000015: np.float32(0.0069250613), 1000017: np.float32(0.006552811), 1000018: np.float32(0.0069742515), 1000019: np.float32(0.0), 1000021: np.float32(0.013845873), 1000023: np.float32(0.0049268506), 1000025: np.float32(0.0030241886), 1000026: np.float32(0.011134537), 1000033: np.float32(0.0008570178), 1000037: np.float32(0.0053728204), 1000040: np.float32(0.008459944), 1000042: np.float32(0.0057643247), 1000043: np.float32(0.0076222145), 1000045: np.float32(0.006254602), 1000046: np.float32(0.00751175), 1000048: np.float32(0.011578849), 1000049: np.float32(0.006046985), 1000050: np.float32(0.0063915146), 1000053: np.float32(0.011818557), 1000056: np.float32(0.0037195198), 1000059: np.float32(0.002841345), 1000060: np.float32(0.0024915761), 1000061: np.float32(0.019150829), 1000063: np.float32(0.000974029), 1000064: np.float32(0.0), 1000068: np.float32(0.0034180444), 1000072: np.float32(0.0024870257), 1000078: np.float32(0.007197562), 1000085: np.float32(0.0), 1000087: np.float32(0.0), 1000088: np.float32(0.0110939825), 1000089: np.float32(0.003734853), 1000094: np.float32(0.0082698995), 1000095: np.float32(0.0), 1000096: np.float32(0.015277575), 1000097: np.float32(0.05559064), 1000101: np.float32(0.0023790456), 1000105: np.float32(0.0031977515), 1000106: np.float32(0.00341471), 1000107: np.float32(0.0022100005), 1000108: np.float32(0.008729817), 1000110: np.float32(0.00797307), 1000113: np.float32(0.0061829975), 1000115: np.float32(0.007937759), 1000116: np.float32(0.0031645845), 1000120: np.float32(0.018221006), 1000123: np.float32(0.0052237464), 1000131: np.float32(0.010780849), 1000132: np.float32(0.0105603365), 1000136: np.float32(0.0049818964), 1000137: np.float32(0.0042282217), 1000139: np.float32(0.004134339), 1000146: np.float32(0.050686684), 1000152: np.float32(0.006306883), 1000154: np.float32(0.0062974887), 1000156: np.float32(0.0076816017), 1000158: np.float32(0.0076881107), 1000162: np.float32(0.009247229), 1000166: np.float32(0.02255683), 1000168: np.float32(1.896054e-05), 1000171: np.float32(0.017346878), 1000174: np.float32(0.00691919), 1000176: np.float32(0.0075078583), 1000183: np.float32(0.0055392417), 1000185: np.float32(0.0), 1000188: np.float32(0.0024098156), 1000189: np.float32(0.011088272), 1000194: np.float32(0.004549121), 1000197: np.float32(0.0041362005), 1000202: np.float32(0.02038093), 1000209: np.float32(0.009975403), 1000212: np.float32(0.013226993), 1000215: np.float32(0.031827867), 1000226: np.float32(0.0025783714), 1000233: np.float32(0.0), 1000234: np.float32(0.012631429), 1000235: np.float32(0.0), 1000237: np.float32(0.006301798), 1000240: np.float32(0.00470084), 1000251: np.float32(0.0027604273), 1000259: np.float32(0.0034356092), 1000266: np.float32(0.003207312), 1000271: np.float32(0.010223378), 1000297: np.float32(0.0036211018), 1000301: np.float32(0.0061581857), 1000303: np.float32(0.0), 1000305: np.float32(0.0), 1000306: np.float32(0.010871347), 1000321: np.float32(0.0044806115), 1000325: np.float32(0.006324336), 1000326: np.float32(0.0019316645), 1000337: np.float32(0.0019821408), 1000339: np.float32(0.00014848351), 1000341: np.float32(0.0052271397), 1000342: np.float32(0.0029939145), 1000373: np.float32(0.023279104), 1000375: np.float32(0.0149818165), 1000379: np.float32(0.014294851), 1000381: np.float32(0.006152044), 1000385: np.float32(0.0), 1000388: np.float32(0.044072177), 1000392: np.float32(0.0040213005), 1000398: np.float32(0.0054421234), 1000404: np.float32(0.003712083), 1000406: np.float32(0.011827206), 1000415: np.float32(0.011057105), 1000424: np.float32(0.0035948802), 1000426: np.float32(0.0047730543), 1000427: np.float32(0.008861682), 1000431: np.float32(0.0038 ...

# %%
check_metrics(metrics, threshold=0.0000001, gt=False)
# Out:
# IDs with metric below 1e-07
# 84 out of 553 total IDs
# [1000019, 1000064, 1000085, 1000087, 1000095, 1000185, 1000233, 1000235, 1000303, 1000305, 1000385, 1000442, 1000456, 1000549, 1000702, 1001189, 1001711, 1001743, 1001899, 1002001, 1002139, 1002193, 1002312, 1003346, 1003631, 1004849, 1004891, 1005361, 1005680, 1005704, 1005788, 1006053, 1007009, 1008715, 1009149, 1009291, 1011481, 1014627, 1014655, 1018863, 1018973, 1019293, 1023710, 1024884, 1029054, 1030767, 1030771, 1031944, 1031947, 1031956, 1032035, 1032401, 1032495, 1032498, 1032501, 1032504, 1032752, 1032755, 1035706, 1035733, 1035766, 1035778, 1035942, 1036087, 1036130, 1036131, 1036132, 1036137, 1036141, 1036159, 1036162, 1036164, 1036165, 1036188, 1036189, 1036199, 1036200, 1036203, 1036229, 1036241, 1036244, 1036250, 1036270, 1036272]
# Different Scene example 1000101: 0.0023790456
# Different Scene example 1000171: 0.017346878
# Correct example 1000166: 0.02255683
# Correct example 1000033: 0.0008570178
# Wrong Times example 1000019: 0.0
# Wrong Times example 1000812: 0.00016215492
# [1000019,
#  1000064,
#  1000085,
#  1000087,
#  1000095,
#  1000185,
#  1000233,
#  1000235,
#  1000303,
#  1000305,
#  1000385,
#  1000442,
#  1000456,
#  1000549,
#  1000702,
#  1001189,
#  1001711,
#  1001743,
#  1001899,
#  1002001,
#  1002139,
#  1002193,
#  1002312,
#  1003346,
#  1003631,
#  1004849,
#  1004891,
#  1005361,
#  1005680,
#  1005704,
#  1005788,
#  1006053,
#  1007009,
#  1008715,
#  1009149,
#  1009291,
#  1011481,
#  1014627,
#  1014655,
#  1018863,
#  1018973,
#  1019293,
#  1023710,
#  1024884,
#  1029054,
#  1030767,
#  1030771,
#  1031944,
#  1031947,
#  1031956,
#  1032035,
#  1032401,
#  1032495,
#  1032498,
#  1032501,
#  1032504,
#  1032752,
#  1032755,
#  1035706,
#  1035733,
#  1035766,
#  1035778,
#  1035942,
#  1036087,
#  1036130,
#  1036131,
#  1036132,
#  1036137,
#  1036141,
#  1036159,
#  1036162,
#  1036164,
#  1036165,
#  1036188,
#  1036189,
#  1036199,
#  1036200,
#  1036203,
#  1036229,
#  1036241,
#  1036244,
#  1036250,
#  1036270,
#  1036272]
